# %%
from concurrent.futures import ThreadPoolExecutor
import os
import cv2
import concurrent.futures
import mediapipe as mp
import json
from pathlib import Path

# %%
src_folder = "./dataset/origin"
dest_folder = "./dataset/plus"

def process_folder(folder_name):
    folder_path = os.path.join(src_folder, folder_name)
    if os.path.isdir(folder_path):
        dest_folder_path = os.path.join(dest_folder, folder_name)
        os.makedirs(dest_folder_path, exist_ok=True)
        for filename in os.listdir(folder_path):
            if filename.endswith(".jpg"):
                img_path = os.path.join(folder_path, filename)
                img = cv2.imread(img_path)
                flipped_img = cv2.flip(img, 1)
                right_img_name = f"{folder_name}_right_{filename}"
                right_img_path = os.path.join(dest_folder_path, right_img_name)
                cv2.imwrite(right_img_path, img)
                left_img_name = f"{folder_name}_left_{filename}"
                left_img_path = os.path.join(dest_folder_path, left_img_name)
                cv2.imwrite(left_img_path, flipped_img)
                
if not os.path.exists(dest_folder):
    os.makedirs(dest_folder)
    num_threads = os.cpu_count() or 1
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        folder_names = os.listdir(src_folder)
        executor.map(process_folder, folder_names)
else:
    print("The destination folder already exists. Skipping processing.")
# Out:
# The destination folder already exists. Skipping processing.

# %%
def normalize_bbox(image_width, image_height, bbox):
    x, y, width, height = bbox
    return x / image_width, y / image_height, width / image_width, height / image_height

def detect_and_draw_hand(image_path, labels, output_image_folder):
    mp_hands = mp.solutions.hands
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_height, image_width, _ = image.shape

    with mp_hands.Hands(static_image_mode=True, max_num_hands=1) as hands:
        results = hands.process(image_rgb)
        normalized_bbox = {}
        file_name = Path(image_path).stem

        if results.multi_hand_landmarks:
            hand_landmarks = results.multi_hand_landmarks[0]
            x_min, y_min = image_width, image_height
            x_max, y_max = 0, 0

            for landmark in hand_landmarks.landmark:
                x, y = int(landmark.x * image_width), int(landmark.y * image_height)
                x_min, y_min = min(x, x_min), min(y, y_min)
                x_max, y_max = max(x, x_max), max(y, y_max)

            padding = 0.1
            x_min = max(0, int(x_min - (x_max - x_min) * padding))
            y_min = max(0, int(y_min - (y_max - y_min) * padding))
            x_max = min(image_width, int(x_max + (x_max - x_min) * padding))
            y_max = min(image_height, int(y_max + (y_max - y_min) * padding))

            normalized_bbox = normalize_bbox(image_width, image_height, (x_min, y_min, x_max - x_min, y_max - y_min))
            cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

            path = f"{output_image_folder}/{labels}"
            os.makedirs(path, exist_ok=True)
            cv2.imwrite(f"{path}/{file_name}.jpg", image)

        return {
            "bboxes": [normalized_bbox],
            "labels": [labels],
            "leading_hand": "Left" if 'left' in file_name else "Right"
        }

def process_image(filename, folder_path, labels, output_image_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(folder_path, filename)
        output_data = detect_and_draw_hand(image_path, labels, output_image_folder)
        return Path(filename).stem, output_data

src_folder = "./dataset/plus"
output_json_folder = "./dataset/json"
output_image_folder = "./dataset/mark"

if not os.path.exists(output_image_folder) or not os.path.exists(output_json_folder):
    os.makedirs(output_image_folder, exist_ok=True)
    os.makedirs(output_json_folder, exist_ok=True)
    for folder_name in os.listdir(src_folder):
        folder_path = os.path.join(src_folder, folder_name)
        labels = os.path.basename(folder_path)
        output_json = f"{output_json_folder}/{labels}.json"
        output_json_data = {}

        with ThreadPoolExecutor() as executor:
            futures = [executor.submit(process_image, filename, folder_path, labels, output_image_folder) for filename in os.listdir(folder_path)]
            for future in concurrent.futures.as_completed(futures):
                result = future.result()
                if result is not None:
                    stem, output_data = result
                    output_json_data[stem] = output_data

        with open(output_json, "w") as json_file:
            json.dump(output_json_data, json_file, indent=4)
else:
    print("Output folders already exist. Skipping processing.")

# %%
def remove_unmatched_files(dataset_plus_path, dataset_mark_path):
    for root, dirs, files in os.walk(dataset_plus_path):
        for file in files:
            plus_file_path = os.path.join(root, file)
            mark_file_path = plus_file_path.replace(dataset_plus_path, dataset_mark_path)
            if not os.path.exists(mark_file_path):
                print("Removing:", plus_file_path)
                os.remove(plus_file_path)
dataset_plus_path = "./dataset/plus"
dataset_mark_path = "./dataset/mark"


remove_unmatched_files(dataset_plus_path, dataset_mark_path)
# Out:
# Removing: ./dataset/plus\A\A_left_A10.jpg
# Removing: ./dataset/plus\A\A_left_A100.jpg
# Removing: ./dataset/plus\A\A_left_A101.jpg
# Removing: ./dataset/plus\A\A_left_A102.jpg
# Removing: ./dataset/plus\A\A_left_A103.jpg
# Removing: ./dataset/plus\A\A_left_A104.jpg
# Removing: ./dataset/plus\A\A_left_A105.jpg
# Removing: ./dataset/plus\A\A_left_A106.jpg
# Removing: ./dataset/plus\A\A_left_A107.jpg
# Removing: ./dataset/plus\A\A_left_A108.jpg
# Removing: ./dataset/plus\A\A_left_A109.jpg
# Removing: ./dataset/plus\A\A_left_A110.jpg
# Removing: ./dataset/plus\A\A_left_A111.jpg
# Removing: ./dataset/plus\A\A_left_A112.jpg
# Removing: ./dataset/plus\A\A_left_A113.jpg
# Removing: ./dataset/plus\A\A_left_A115.jpg
# Removing: ./dataset/plus\A\A_left_A116.jpg
# Removing: ./dataset/plus\A\A_left_A117.jpg
# Removing: ./dataset/plus\A\A_left_A118.jpg
# Removing: ./dataset/plus\A\A_left_A119.jpg
# Removing: ./dataset/plus\A\A_left_A120.jpg
# Removing: ./dataset/plus\A\A_left_A121.jpg
# Removing: ./dataset/plus\A\A_left_A122.jpg
# Removing: ./dataset/plus\A\A_left_A123.jpg
# Removing: ./dataset/plus\A\A_left_A124.jpg
# Removing: ./dataset/plus\A\A_left_A125.jpg
# Removing: ./dataset/plus\A\A_left_A126.jpg
# Removing: ./dataset/plus\A\A_left_A127.jpg
# Removing: ./dataset/plus\A\A_left_A128.jpg
# Removing: ./dataset/plus\A\A_left_A129.jpg
# Removing: ./dataset/plus\A\A_left_A130.jpg
# Removing: ./dataset/plus\A\A_left_A131.jpg
# Removing: ./dataset/plus\A\A_left_A132.jpg
# Removing: ./dataset/plus\A\A_left_A133.jpg
# Removing: ./dataset/plus\A\A_left_A134.jpg
# Removing: ./dataset/plus\A\A_left_A1349.jpg
# Removing: ./dataset/plus\A\A_left_A135.jpg
# Removing: ./dataset/plus\A\A_left_A136.jpg
# Removing: ./dataset/plus\A\A_left_A137.jpg
# Removing: ./dataset/plus\A\A_left_A138.jpg
# Removing: ./dataset/plus\A\A_left_A139.jpg
# Removing: ./dataset/plus\A\A_left_A140.jpg
# Removing: ./dataset/plus\A\A_left_A141.jpg
# Removing: ./dataset/plus\A\A_left_A142.jpg
# Removing: ./dataset/plus\A\A_left_A143.jpg
# Removing: ./dataset/plus\A\A_left_A144.jpg
# Removing: ./dataset/plus\A\A_left_A145.jpg
# Removing: ./dataset/plus\A\A_left_A146.jpg
# Removing: ./dataset/plus\A\A_left_A147.jpg
# Removing: ./dataset/plus\A\A_left_A148.jpg
# Removing: ./dataset/plus\A\A_left_A149.jpg
# Removing: ./dataset/plus\A\A_left_A150.jpg
# Removing: ./dataset/plus\A\A_left_A151.jpg
# Removing: ./dataset/plus\A\A_left_A152.jpg
# Removing: ./dataset/plus\A\A_left_A153.jpg
# Removing: ./dataset/plus\A\A_left_A154.jpg
# Removing: ./dataset/plus\A\A_left_A155.jpg
# Removing: ./dataset/plus\A\A_left_A156.jpg
# Removing: ./dataset/plus\A\A_left_A157.jpg
# Removing: ./dataset/plus\A\A_left_A158.jpg
# Removing: ./dataset/plus\A\A_left_A159.jpg
# Removing: ./dataset/plus\A\A_left_A160.jpg
# Removing: ./dataset/plus\A\A_left_A161.jpg
# Removing: ./dataset/plus\A\A_left_A162.jpg
# Removing: ./dataset/plus\A\A_left_A163.jpg
# Removing: ./dataset/plus\A\A_left_A164.jpg
# Removing: ./dataset/plus\A\A_left_A165.jpg
# Removing: ./dataset/plus\A\A_left_A166.jpg
# Removing: ./dataset/plus\A\A_left_A167.jpg
# Removing: ./dataset/plus\A\A_left_A168.jpg
# Removing: ./dataset/plus\A\A_left_A169.jpg
# Removing: ./dataset/plus\A\A_left_A170.jpg
# Removing: ./dataset/plus\A\A_left_A171.jpg
# Removing: ./dataset/plus\A\A_left_A172.jpg
# Removing: ./dataset/plus\A\A_left_A173.jpg
# Removing: ./dataset/plus\A\A_left_A174.jpg
# Removing: ./dataset/plus\A\A_left_A175.jpg
# Removing: ./dataset/plus\A\A_left_A176.jpg
# Removing: ./dataset/plus\A\A_left_A177.jpg
# Removing: ./dataset/plus\A\A_left_A178.jpg
# Removing: ./dataset/plus\A\A_left_A179.jpg
# Removing: ./dataset/plus\A\A_left_A180.jpg
# Removing: ./dataset/plus\A\A_left_A181.jpg
# Removing: ./dataset/plus\A\A_left_A182.jpg
# Removing: ./dataset/plus\A\A_left_A183.jpg
# Removing: ./dataset/plus\A\A_left_A184.jpg
# Removing: ./dataset/plus\A\A_left_A185.jpg
# Removing: ./dataset/plus\A\A_left_A186.jpg
# Removing: ./dataset/plus\A\A_left_A187.jpg
# Removing: ./dataset/plus\A\A_left_A188.jpg
# Removing: ./dataset/plus\A\A_left_A189.jpg
# Removing: ./dataset/plus\A\A_left_A190.jpg
# Removing: ./dataset/plus\A\A_left_A191.jpg
# Removing: ./dataset/plus\A\A_left_A192.jpg
# Removing: ./dataset/plus\A\A_left_A193.jpg
# Removing: ./dataset/plus\A\A_left_A194.jpg
# Removing: ./dataset/plus\A\A_left_A195.jpg
# Removing: ./dataset/plus\A\A_left_A196.jpg
# Removing: ./dataset/plus\A\A_left_A197.jpg
# Removing: ./dataset/plus\A\A_left_A198.jpg
# Removing: ./dataset/plus\A\A_left_A199.jpg
# Removing: ./dataset/plus\A\A_left_A200.jpg
# Removing: ./dataset/plus\A\A_left_A2006.jpg
# Removing: ./dataset/plus\A\A_left_A201.jpg
# Removing: ./dataset/plus\A\A_left_A202.jpg
# Removing: ./dataset/plus\A\A_left_A203.jpg
# Removing: ./dataset/plus\A\A_left_A204.jpg
# Removing: ./dataset/plus\A\A_left_A205.jpg
# Removing: ./dataset/plus\A\A_left_A206.jpg
# Removing: ./dataset/plus\A\A_left_A207.jpg
# Removing: ./dataset/plus\A\A_left_A208.jpg
# Removing: ./dataset/plus\A\A_left_A209.jpg
# Removing: ./dataset/plus\A\A_left_A210.jpg
# Removing: ./dataset/plus\A\A_left_A211.jpg
# Removing: ./dataset/plus\A\A_left_A212.jpg
# Removing: ./dataset/plus\A\A_left_A213.jpg
# Removing: ./dataset/plus\A\A_left_A214.jpg
# Removing: ./dataset/plus\A\A_left_A215.jpg
# Removing: ./dataset/plus\A\A_left_A216.jpg
# Removing: ./dataset/plus\A\A_left_A217.jpg
# Removing: ./dataset/plus\A\A_left_A218.jpg
# Removing: ./dataset/plus\A\A_left_A219.jpg
# Removing: ./dataset/plus\A\A_left_A220.jpg
# Removing: ./dataset/plus\A\A_left_A221.jpg
# Removing: ./dataset/plus\A\A_left_A222.jpg
# Removing: ./dataset/plus\A\A_left_A223.jpg
# Removing: ./dataset/plus\A\A_left_A224.jpg
# Removing: ./dataset/plus\A\A_left_A225.jpg
# Removing: ./dataset/plus\A\A_left_A226.jpg
# Removing: ./dataset/plus\A\A_left_A227.jpg
# Removing: ./dataset/plus\A\A_left_A228.jpg
# Removing: ./dataset/plus\A\A_left_A229.jpg
# Removing: ./dataset/plus\A\A_left_A230.jpg
# Removing: ./dataset/plus\A\A_left_A231.jpg
# Removing: ./dataset/plus\A\A_left_A232.jpg
# Removing: ./dataset/plus\A\A_left_A233.jpg
# Removing: ./dataset/plus\A\A_left_A234.jpg
# Removing: ./dataset/plus\A\A_left_A235.jpg
# Removing: ./dataset/plus\A\A_left_A236.jpg
# Removing: ./dataset/plus\A\A_left_A237.jpg
# Removing: ./dataset/plus\A\A_left_A238.jpg
# Removing: ./dataset/plus\A\A_left_A239.jpg
# Removing: ./dataset/plus\A\A_left_A240.jpg
# Removing: ./dataset/plus\A\A_left_A241.jpg
# Removing: ./dataset/plus\A\A_left_A2416.jpg
# Removing: ./dataset/plus\A\A_left_A2418.jpg
# Removing: ./dataset/plus\A\A_left_A2419.jpg
# Removing: ./dataset/plus\A\A_left_A242.jpg
# Removing: ./dataset/plus\A\A_left_A2422.jpg
# Removing: ./dataset/plus\A\A_left_A2423.jpg
# Removing: ./dataset/plus\A\A_left_A2424.jpg
# Removing: ./dataset/plus\A\A_left_A2425.jpg
# Removing: ./dataset/plus\A\A_left_A2426.jpg
# Removing: ./dataset/plus\A\A_left_A2427.jpg
# Removing: ./dataset/plus\A\A_left_A2428.jpg
# Removing: ./dataset/plus\A\A_left_A2429.jpg
# Removing: ./dataset/plus\A\A_left_A243.jpg
# Removing: ./dataset/plus\A\A_left_A2430.jpg
# Removing: ./dataset/plus\A\A_left_A2433.jpg
# Removing: ./dataset/plus\A\A_left_A2434.jpg
# Removing: ./dataset/plus\A\A_left_A2435.jpg
# Removing: ./dataset/plus\A\A_left_A2436.jpg
# Removing: ./dataset/plus\A\A_left_A2437.jpg
# Removing: ./dataset/plus\A\A_left_A2438.jpg
# Removing: ./dataset/plus\A\A_left_A2439.jpg
# Removing: ./dataset/plus\A\A_left_A244.jpg
# Removing: ./dataset/plus\A\A_left_A2440.jpg
# Removing: ./dataset/plus\A\A_left_A2441.jpg
# Removing: ./dataset/plus\A\A_left_A2442.jpg
# Removing: ./dataset/plus\A\A_left_A2443.jpg
# Removing: ./dataset/plus\A\A_left_A2444.jpg
# Removing: ./dataset/plus\A\A_left_A245.jpg
# Removing: ./dataset/plus\A\A_left_A2459.jpg
# Removing: ./dataset/plus\A\A_left_A246.jpg
# Removing: ./dataset/plus\A\A_left_A2460.jpg
# Removing: ./dataset/plus\A\A_left_A2464.jpg
# Removing: ./dataset/plus\A\A_left_A2465.jpg
# Removing: ./dataset/plus\A\A_left_A2466.jpg
# Removing: ./dataset/plus\A\A_left_A2467.jpg
# Removing: ./dataset/plus\A\A_left_A2468.jpg
# Removing: ./dataset/plus\A\A_left_A2469.jpg
# Removing: ./dataset/plus\A\A_left_A247.jpg
# Removing: ./dataset/plus\A\A_left_A2470.jpg
# Removing: ./dataset/plus\A\A_left_A2473.jpg
# Removing: ./dataset/plus\A\A_left_A2474.jpg
# Removing: ./dataset/plus\A\A_left_A2475.jpg
# Removing: ./dataset/plus\A\A_left_A2476.jpg
# Removing: ./dataset/plus\A\A_left_A2477.jpg
# Removing: ./dataset/plus\A\A_left_A2478.jpg
# Removing: ./dataset/plus\A\A_left_A2479.jpg
# Removing: ./dataset/plus\A\A_left_A248.jpg
# Removing: ./dataset/plus\A\A_left_A2480.jpg
# Removing: ./dataset/plus\A\A_left_A2483.jpg
# Removing: ./dataset/plus\A\A_left_A2484.jpg
# Removing: ./dataset/plus\A\A_left_A2485.jpg
# Removing: ./dataset/plus\A\A_left_A2486.jpg
# Removing: ./dataset/plus\A\A_left_A2487.jpg
# Removing: ./dataset/plus\A\A_left_A2488.jpg
# Removing: ./dataset/plus\A\A_left_A2489.jpg
# Removing: ./dataset/plus\A\A_left_A249.jpg
# Removing: ./dataset/plus\A\A_left_A2490.jpg
# Removing: ./dataset/plus\A\A_left_A2491.jpg
# Removing: ./dataset/plus\A\A_left_A2492.jpg
# Removing: ./dataset/plus\A\A_left_A2493.jpg
# Removing: ./dataset/plus\A\A_left_A2494.jpg
# Removing: ./dataset/plus\A\A_left_A2495.jpg
# Removing: ./dataset/plus\A\A_left_A2496.jpg
# Removing: ./dataset/plus\A\A_left_A2497.jpg
# Removing: ./dataset/plus\A\A_left_A2498.jpg
# Removing: ./dataset/plus\A\A_left_A2499.jpg
# Removing: ./dataset/plus\A\A_left_A250.jpg
# Removing: ./dataset/plus\A\A_left_A2500.jpg
# Removing: ./dataset/plus\A\A_left_A2501.jpg
# Removing: ./dataset/plus\A\A_left_A2502.jpg
# Removing: ./dataset/plus\A\A_left_A2503.jpg
# Removing: ./dataset/plus\A\A_left_A2504.jpg
# Removing: ./dataset/plus\A\A_left_A2505.jpg
# Removing: ./dataset/plus\A\A_left_A2506.jpg
# Removing: ./dataset/plus\A\A_left_A2507.jpg
# Removing: ./dataset/plus\A\A_left_A2508.jpg
# Removing: ./dataset/plus\A\A_left_A2509.jpg
# Removing: ./dataset/plus\A\A_left_A251.jpg
# Removing: ./dataset/plus\A\A_left_A2510.jpg
# Removing: ./dataset/plus\A\A_left_A2511.jpg
# Removing: ./dataset/plus\A\A_left_A2512.jpg
# Removing: ./dataset/plus\A\A_left_A2513.jpg
# Removing: ./dataset/plus\A\A_left_A2514.jpg
# Removing: ./dataset/plus\A\A_left_A2515.jpg
# Removing: ./dataset/plus\A\A_left_A2516.jpg
# Removing: ./dataset/plus\A\A_left_A2517.jpg
# Removing: ./dataset/plus\A\A_left_A2518.jpg
# Removing: ./dataset/plus\A\A_left_A2519.jpg
# Removing: ./dataset/plus\A\A_left_A252.jpg
# Removing: ./dataset/plus\A\A_left_A2520.jpg
# Removing: ./dataset/plus\A\A_left_A2521.jpg
# Removing: ./dataset/plus\A\A_left_A2522.jpg
# Removing: ./dataset/plus\A\A_left_A2524.jpg
# Removing: ./dataset/plus\A\A_left_A2525.jpg
# Removing: ./dataset/plus\A\A_left_A2526.jpg
# Removing: ./dataset/plus\A\A_left_A2527.jpg
# Removing: ./dataset/plus\A\A_left_A2529.jpg
# Removing: ./dataset/plus\A\A_left_A253.jpg
# Removing: ./dataset/plus\A\A_left_A2530.jpg
# Removing: ./dataset/plus\A\A_left_A2531.jpg
# Removing: ./dataset/plus\A\A_left_A2532.jpg
# Removing: ./dataset/plus\A\A_left_A2533.jpg
# Removing: ./dataset/plus\A\A_left_A2534.jpg
# Removing: ./dataset/plus\A\A_left_A2535.jpg
# Removing: ./dataset/plus\A\A_left_A2536.jpg
# Removing: ./dataset/plus\A\A_left_A254.jpg
# Removing: ./dataset/plus\A\A_left_A2545.jpg
# Removing: ./dataset/plus\A\A_left_A2549.jpg
# Removing: ./dataset/plus\A\A_left_A255.jpg
# Removing: ./dataset/plus\A\A_left_A2550.jpg
# Removing: ./dataset/plus\A\A_left_A2551.jpg
# Removing: ./dataset/plus\A\A_left_A2552.jpg
# Removing: ./dataset/plus\A\A_left_A2553.jpg
# Removing: ./dataset/plus\A\A_left_A2554.jpg
# Removing: ./dataset/plus\A\A_left_A2555.jpg
# Removing: ./dataset/plus\A\A_left_A2556.jpg
# Removing: ./dataset/plus\A\A_left_A2557.jpg
# Removing: ./dataset/plus\A\A_left_A256.jpg
# Removing: ./dataset/plus\A\A_left_A2560.jpg
# Removing: ./dataset/plus\A\A_left_A2561.jpg
# Removing: ./dataset/plus\A\A_left_A2567.jpg
# Removing: ./dataset/plus\A\A_left_A2568.jpg
# Removing: ./dataset/plus\A\A_left_A2569.jpg
# Removing: ./dataset/plus\A\A_left_A257.jpg
# Removing: ./dataset/plus\A\A_left_A2570.jpg
# Removing: ./dataset/plus\A\A_left_A2571.jpg
# Removing: ./dataset/plus\A\A_left_A2572.jpg
# Removing: ./dataset/plus\A\A_left_A2575.jpg
# Removing: ./dataset/plus\A\A_left_A258.jpg
# Removing: ./dataset/plus\A\A_left_A2580.jpg
# Removing: ./dataset/plus\A\A_left_A2581.jpg
# Removing: ./dataset/plus\A\A_left_A2582.jpg
# Removing: ./dataset/plus\A\A_left_A2583.jpg
# Removing: ./dataset/plus\A\A_left_A2584.jpg
# Removing: ./dataset/plus\A\A_left_A2585.jpg
# Removing: ./dataset/plus\A\A_left_A2586.jpg
# Removing: ./dataset/plus\A\A_left_A2587.jpg
# Removing: ./dataset/plus\A\A_left_A2588.jpg
# Removing: ./dataset/plus\A\A_left_A2589.jpg
# Removing: ./dataset/plus\A\A_left_A259.jpg
# Removing: ./dataset/plus\A\A_left_A2590.jpg
# Removing: ./dataset/plus\A\A_left_A2591.jpg
# Removing: ./dataset/plus\A\A_left_A2592.jpg
# Removing: ./dataset/plus\A\A_left_A2593.jpg
# Removing: ./dataset/plus\A\A_left_A2595.jpg
# Removing: ./dataset/plus\A\A_left_A2596.jpg
# Removing: ./dataset/plus\A\A_left_A2597.jpg
# Removing: ./dataset/plus\A\A_left_A2598.jpg
# Removing: ./dataset/plus\A\A_left_A2599.jpg
# Removing: ./dataset/plus\A\A_left_A260.jpg
# Removing: ./dataset/plus\A\A_left_A2600.jpg
# Removing: ./dataset/plus\A\A_left_A2601.jpg
# Removing: ./dataset/plus\A\A_left_A2602.jpg
# Removing: ./dataset/plus\A\A_left_A2603.jpg
# Removing: ./dataset/plus\A\A_left_A2604.jpg
# Removing: ./dataset/plus\A\A_left_A2605.jpg
# Removing: ./dataset/plus\A\A_left_A2606.jpg
# Removing: ./dataset/plus\A\A_left_A2607.jpg
# Removing: ./dataset/plus\A\A_left_A2608.jpg
# Removing: ./dataset/plus\A\A_left_A2609.jpg
# Removing: ./dataset/plus\A\A_left_A261.jpg
# Removing: ./dataset/plus\A\A_left_A2610.jpg
# Removing: ./dataset/plus\A\A_left_A2611.jpg
# Removing: ./dataset/plus\A\A_left_A2612.jpg
# Removing: ./dataset/plus\A\A_left_A2613.jpg
# Removing: ./dataset/plus\A\A_left_A2614.jpg
# Removing: ./dataset/plus\A\A_left_A2615.jpg
# Removing: ./dataset/plus\A\A_left_A2616.jpg
# Removing: ./dataset/plus\A\A_left_A2617.jpg
# Removing: ./dataset/plus\A\A_left_A2618.jpg
# Removing: ./dataset/plus\A\A_left_A2619.jpg
# Removing: ./dataset/plus\A\A_left_A262.jpg
# Removing: ./dataset/plus\A\A_left_A2620.jpg
# Removing: ./dataset/plus\A\A_left_A2621.jpg
# Removing: ./dataset/plus\A\A_left_A2622.jpg
# Removing: ./dataset/plus\A\A_left_A2623.jpg
# Removing: ./dataset/plus\A\A_left_A2624.jpg
# Removing: ./dataset/plus\A\A_left_A2625.jpg
# Removing: ./dataset/plus\A\A_left_A2626.jpg
# Removing: ./dataset/plus\A\A_left_A2627.jpg
# Removing: ./dataset/plus\A\A_left_A2628.jpg
# Removing: ./dataset/plus\A\A_left_A2629.jpg
# Removing: ./dataset/plus\A\A_left_A263.jpg
# Removing: ./dataset/plus\A\A_left_A2630.jpg
# Removing: ./dataset/plus\A\A_left_A264.jpg
# Removing: ./dataset/plus\A\A_left_A265.jpg
# Removing: ./dataset/plus\A\A_left_A266.jpg
# Removing: ./dataset/plus\A\A_left_A267.jpg
# Removing: ./dataset/plus\A\A_left_A268.jpg
# Removing: ./dataset/plus\A\A_left_A2686.jpg
# Removing: ./dataset/plus\A\A_left_A2687.jpg
# Removing: ./dataset/plus\A\A_left_A2688.jpg
# Removing: ./dataset/plus\A\A_left_A2689.jpg
# Removing: ./dataset/plus\A\A_left_A269.jpg
# Removing: ./dataset/plus\A\A_left_A2690.jpg
# Removing: ./dataset/plus\A\A_left_A2691.jpg
# Removing: ./dataset/plus\A\A_left_A2692.jpg
# Removing: ./dataset/plus\A\A_left_A2693.jpg
# Removing: ./dataset/plus\A\A_left_A2694.jpg
# Removing: ./dataset/plus\A\A_left_A2695.jpg
# Removing: ./dataset/plus\A\A_left_A2696.jpg
# Removing: ./dataset/plus\A\A_left_A2697.jpg
# Removing: ./dataset/plus\A\A_left_A2698.jpg
# Removing: ./dataset/plus\A\A_left_A2699.jpg
# Removing: ./dataset/plus\A\A_left_A270.jpg
# Removing: ./dataset/plus\A\A_left_A2700.jpg
# Removing: ./dataset/plus\A\A_left_A2701.jpg
# Removing: ./dataset/plus\A\A_left_A2702.jpg
# Removing: ./dataset/plus\A\A_left_A2703.jpg
# Removing: ./dataset/plus\A\A_left_A2704.jpg
# Removing: ./dataset/plus\A\A_left_A2705.jpg
# Removing: ./dataset/plus\A\A_left_A2706.jpg
# Removing: ./dataset/plus\A\A_left_A2707.jpg
# Removing: ./dataset/plus\A\A_left_A2708.jpg
# Removing: ./dataset/plus\A\A_left_A271.jpg
# Removing: ./dataset/plus\A\A_left_A2710.jpg
# Removing: ./dataset/plus\A\A_left_A2711.jpg
# Removing: ./dataset/plus\A\A_left_A2712.jpg
# Removing: ./dataset/plus\A\A_left_A2713.jpg
# Removing: ./dataset/plus\A\A_left_A2714.jpg
# Removing: ./dataset/plus\A\A_left_A2715.jpg
# Removing: ./dataset/plus\A\A_left_A2716.jpg
# Removing: ./dataset/plus\A\A_left_A2717.jpg
# Removing: ./dataset/plus\A\A_left_A2718.jpg
# Removing: ./dataset/plus\A\A_left_A2719.jpg
# Removing: ./dataset/plus\A\A_left_A272.jpg
# Removing: ./dataset/plus\A\A_left_A2720.jpg
# Removing: ./dataset/plus\A\A_left_A2721.jpg
# Removing: ./dataset/plus\A\A_left_A2722.jpg
# Removing: ./dataset/plus\A\A_left_A2723.jpg
# Removing: ./dataset/plus\A\A_left_A2724.jpg
# Removing: ./dataset/plus\A\A_left_A2725.jpg
# Removing: ./dataset/plus\A\A_left_A2726.jpg
# Removing: ./dataset/plus\A\A_left_A2727.jpg
# Removing: ./dataset/plus\A\A_left_A2728.jpg
# Removing: ./dataset/plus\A\A_left_A2729.jpg
# Removing: ./dataset/plus\A\A_left_A273.jpg
# Removing: ./dataset/plus\A\A_left_A2730.jpg
# Removing: ./dataset/plus\A\A_left_A2731.jpg
# Removing: ./dataset/plus\A\A_left_A2732.jpg
# Removing: ./dataset/plus\A\A_left_A2733.jpg
# Removing: ./dataset/plus\A\A_left_A2734.jpg
# Removing: ./dataset/plus\A\A_left_A2735.jpg
# Removing: ./dataset/plus\A\A_left_A2736.jpg
# Removing: ./dataset/plus\A\A_left_A2737.jpg
# Removing: ./dataset/plus\A\A_left_A2738.jpg
# Removing: ./dataset/plus\A\A_left_A2739.jpg
# Removing: ./dataset/plus\A\A_left_A274.jpg
# Removing: ./dataset/plus\A\A_left_A2740.jpg
# Removing: ./dataset/plus\A\A_left_A2741.jpg
# Removing: ./dataset/plus\A\A_left_A2742.jpg
# Removing: ./dataset/plus\A\A_left_A2743.jpg
# Removing: ./dataset/plus\A\A_left_A2744.jpg
# Removing: ./dataset/plus\A\A_left_A2745.jpg
# Removing: ./dataset/plus\A\A_left_A2746.jpg
# Removing: ./dataset/plus\A\A_left_A2747.jpg
# Removing: ./dataset/plus\A\A_left_A2748.jpg
# Removing: ./dataset/plus\A\A_left_A2749.jpg
# Removing: ./dataset/plus\A\A_left_A275.jpg
# Removing: ./dataset/plus\A\A_left_A2750.jpg
# Removing: ./dataset/plus\A\A_left_A2751.jpg
# Removing: ./dataset/plus\A\A_left_A2752.jpg
# Removing: ./dataset/plus\A\A_left_A2753.jpg
# Removing: ./dataset/plus\A\A_left_A2754.jpg
# Removing: ./dataset/plus\A\A_left_A2755.jpg
# Removing: ./dataset/plus\A\A_left_A2756.jpg
# Removing: ./dataset/plus\A\A_left_A2757.jpg
# Removing: ./dataset/plus\A\A_left_A2758.jpg
# Removing: ./dataset/plus\A\A_left_A2759.jpg
# Removing: ./dataset/plus\A\A_left_A276.jpg
# Removing: ./dataset/plus\A\A_left_A2760.jpg
# Removing: ./dataset/plus\A\A_left_A2761.jpg
# Removing: ./dataset/plus\A\A_left_A2762.jpg
# Removing: ./dataset/plus\A\A_left_A2763.jpg
# Removing: ./dataset/plus\A\A_left_A2764.jpg
# Removing: ./dataset/plus\A\A_left_A2765.jpg
# Removing: ./dataset/plus\A\A_left_A2766.jpg
# Removing: ./dataset/plus\A\A_left_A2767.jpg
# Removing: ./dataset/plus\A\A_left_A2768.jpg
# Removing: ./dataset/plus\A\A_left_A2769.jpg
# Removing: ./dataset/plus\A\A_left_A277.jpg
# Removing: ./dataset/plus\A\A_left_A2770.jpg
# Removing: ./dataset/plus\A\A_left_A2771.jpg
# Removing: ./dataset/plus\A\A_left_A2772.jpg
# Removing: ./dataset/plus\A\A_left_A2773.jpg
# Removing: ./dataset/plus\A\A_left_A2774.jpg
# Removing: ./dataset/plus\A\A_left_A2775.jpg
# Removing: ./dataset/plus\A\A_left_A2776.jpg
# Removing: ./dataset/plus\A\A_left_A2777.jpg
# Removing: ./dataset/plus\A\A_left_A2778.jpg
# Removing: ./dataset/plus\A\A_left_A2779.jpg
# Removing: ./dataset/plus\A\A_left_A278.jpg
# Removing: ./dataset/plus\A\A_left_A2780.jpg
# Removing: ./dataset/plus\A\A_left_A2781.jpg
# Removing: ./dataset/plus\A\A_left_A2782.jpg
# Removing: ./dataset/plus\A\A_left_A2783.jpg
# Removing: ./dataset/plus\A\A_left_A2784.jpg
# Removing: ./dataset/plus\A\A_left_A2785.jpg
# Removing: ./dataset/plus\A\A_left_A2786.jpg
# Removing: ./dataset/plus\A\A_left_A2787.jpg
# Removing: ./dataset/plus\A\A_left_A2788.jpg
# Removing: ./dataset/plus\A\A_left_A2789.jpg
# Removing: ./dataset/plus\A\A_left_A279.jpg
# Removing: ./dataset/plus\A\A_left_A2790.jpg
# Removing: ./dataset/plus\A\A_left_A2791.jpg
# Removing: ./dataset/plus\A\A_left_A2792.jpg
# Removing: ./dataset/plus\A\A_left_A2793.jpg
# Removing: ./dataset/plus\A\A_left_A2794.jpg
# Removing: ./dataset/plus\A\A_left_A2795.jpg
# Removing: ./dataset/plus\A\A_left_A2796.jpg
# Removing: ./dataset/plus\A\A_left_A2797.jpg
# Removing: ./dataset/plus\A\A_left_A2798.jpg
# Removing: ./dataset/plus\A\A_left_A2799.jpg
# Removing: ./dataset/plus\A\A_left_A280.jpg
# Removing: ./dataset/plus\A\A_left_A2800.jpg
# Removing: ./dataset/plus\A\A_left_A2801.jpg
# Removing: ./dataset/plus\A\A_left_A2802.jpg
# Removing: ./dataset/plus\A\A_left_A2803.jpg
# Removing: ./dataset/plus\A\A_left_A2804.jpg
# Removing: ./dataset/plus\A\A_left_A2805.jpg
# Removing: ./dataset/plus\A\A_left_A2806.jpg
# Removing: ./dataset/plus\A\A_left_A2807.jpg
# Removing: ./dataset/plus\A\A_left_A2808.jpg
# Removing: ./dataset/plus\A\A_left_A2809.jpg
# Removing: ./dataset/plus\A\A_left_A281.jpg
# Removing: ./dataset/plus\A\A_left_A2810.jpg
# Removing: ./dataset/plus\A\A_left_A2811.jpg
# Removing: ./dataset/plus\A\A_left_A2812.jpg
# Removing: ./dataset/plus\A\A_left_A2813.jpg
# Removing: ./dataset/plus\A\A_left_A2814.jpg
# Removing: ./dataset/plus\A\A_left_A2815.jpg
# Removing: ./dataset/plus\A\A_left_A2816.jpg
# Removing: ./dataset/plus\A\A_left_A2817.jpg
# Removing: ./dataset/plus\A\A_left_A2818.jpg
# Removing: ./dataset/plus\A\A_left_A2819.jpg
# Removing: ./dataset/plus\A\A_left_A282.jpg
# Removing: ./dataset/plus\A\A_left_A2820.jpg
# Removing: ./dataset/plus\A\A_left_A2821.jpg
# Removing: ./dataset/plus\A\A_left_A2822.jpg
# Removing: ./dataset/plus\A\A_left_A2823.jpg
# Removing: ./dataset/plus\A\A_left_A2824.jpg
# Removing: ./dataset/plus\A\A_left_A2825.jpg
# Removing: ./dataset/plus\A\A_left_A2826.jpg
# Removing: ./dataset/plus\A\A_left_A2827.jpg
# Removing: ./dataset/plus\A\A_left_A2828.jpg
# Removing: ./dataset/plus\A\A_left_A2829.jpg
# Removing: ./dataset/plus\A\A_left_A283.jpg
# Removing: ./dataset/plus\A\A_left_A2830.jpg
# Removing: ./dataset/plus\A\A_left_A2831.jpg
# Removing: ./dataset/plus\A\A_left_A2832.jpg
# Removing: ./dataset/plus\A\A_left_A2833.jpg
# Removing: ./dataset/plus\A\A_left_A2834.jpg
# Removing: ./dataset/plus\A\A_left_A2835.jpg
# Removing: ./dataset/plus\A\A_left_A2836.jpg
# Removing: ./dataset/plus\A\A_left_A2837.jpg
# Removing: ./dataset/plus\A\A_left_A2838.jpg
# Removing: ./dataset/plus\A\A_left_A2839.jpg
# Removing: ./dataset/plus\A\A_left_A2840.jpg
# Removing: ./dataset/plus\A\A_left_A2841.jpg
# Removing: ./dataset/plus\A\A_left_A2842.jpg
# Removing: ./dataset/plus\A\A_left_A2844.jpg
# Removing: ./dataset/plus\A\A_left_A2845.jpg
# Removing: ./dataset/plus\A\A_left_A2846.jpg
# Removing: ./dataset/plus\A\A_left_A2847.jpg
# Removing: ./dataset/plus\A\A_left_A2848.jpg
# Removing: ./dataset/plus\A\A_left_A2849.jpg
# Removing: ./dataset/plus\A\A_left_A285.jpg
# Removing: ./dataset/plus\A\A_left_A2850.jpg
# Removing: ./dataset/plus\A\A_left_A2851.jpg
# Removing: ./dataset/plus\A\A_left_A2852.jpg
# Removing: ./dataset/plus\A\A_left_A2853.jpg
# Removing: ./dataset/plus\A\A_left_A2854.jpg
# Removing: ./dataset/plus\A\A_left_A2858.jpg
# Removing: ./dataset/plus\A\A_left_A286.jpg
# Removing: ./dataset/plus\A\A_left_A2860.jpg
# Removing: ./dataset/plus\A\A_left_A2861.jpg
# Removing: ./dataset/plus\A\A_left_A2862.jpg
# Removing: ./dataset/plus\A\A_left_A2863.jpg
# Removing: ./dataset/plus\A\A_left_A2864.jpg
# Removing: ./dataset/plus\A\A_left_A2865.jpg
# Removing: ./dataset/plus\A\A_left_A2866.jpg
# Removing: ./dataset/plus\A\A_left_A2867.jpg
# Removing: ./dataset/plus\A\A_left_A2868.jpg
# Removing: ./dataset/plus\A\A_left_A2869.jpg
# Removing: ./dataset/plus\A\A_left_A287.jpg
# Removing: ./dataset/plus\A\A_left_A2870.jpg
# Removing: ./dataset/plus\A\A_left_A2871.jpg
# Removing: ./dataset/plus\A\A_left_A2872.jpg
# Removing: ./dataset/plus\A\A_left_A2873.jpg
# Removing: ./dataset/plus\A\A_left_A2874.jpg
# Removing: ./dataset/plus\A\A_left_A2875.jpg
# Removing: ./dataset/plus\A\A_left_A2876.jpg
# Removing: ./dataset/plus\A\A_left_A2877.jpg
# Removing: ./dataset/plus\A\A_left_A2878.jpg
# Removing: ./dataset/plus\A\A_left_A2879.jpg
# Removing: ./dataset/plus\A\A_left_A288.jpg
# Removing: ./dataset/plus\A\A_left_A2880.jpg
# Removing: ./dataset/plus\A\A_left_A2881.jpg
# Removing: ./dataset/plus\A\A_left_A2882.jpg
# Removing: ./dataset/plus\A\A_left_A2883.jpg
# Removing: ./dataset/plus\A\A_left_A2884.jpg
# Removing: ./dataset/plus\A\A_left_A2885.jpg
# Removing: ./dataset/plus\A\A_left_A2886.jpg
# Removing: ./dataset/plus\A\A_left_A2887.jpg
# Removing: ./dataset/plus\A\A_left_A2888.jpg
# Removing: ./dataset/plus\A\A_left_A2889.jpg
# Removing: ./dataset/plus\A\A_left_A289.jpg
# Removing: ./dataset/plus\A\A_left_A2890.jpg
# Removing: ./dataset/plus\A\A_left_A2891.jpg
# Removing: ./dataset/plus\A\A_left_A2892.jpg
# Removing: ./dataset/plus\A\A_left_A2893.jpg
# Removing: ./dataset/plus\A\A_left_A2894.jpg
# Removing: ./dataset/plus\A\A_left_A2895.jpg
# Removing: ./dataset/plus\A\A_left_A2896.jpg
# Removing: ./dataset/plus\A\A_left_A2897.jpg
# Removing: ./dataset/plus\A\A_left_A2898.jpg
# Removing: ./dataset/plus\A\A_left_A2899.jpg
# Removing: ./dataset/plus\A\A_left_A290.jpg
# Removing: ./dataset/plus\A\A_left_A2900.jpg
# Removing: ./dataset/plus\A\A_left_A2901.jpg
# Removing: ./dataset/plus\A\A_left_A2902.jpg
# Removing: ./dataset/plus\A\A_left_A2903.jpg
# Removing: ./dataset/plus\A\A_left_A2904.jpg
# Removing: ./dataset/plus\A\A_left_A2905.jpg
# Removing: ./dataset/plus\A\A_left_A2906.jpg
# Removing: ./dataset/plus\A\A_left_A2907.jpg
# Removing: ./dataset/plus\A\A_left_A2908.jpg
# Removing: ./dataset/plus\A\A_left_A2909.jpg
# Removing: ./dataset/plus\A\A_left_A291.jpg
# Removing: ./dataset/plus\A\A_left_A2910.jpg
# Removing: ./dataset/plus\A\A_left_A2911.jpg
# Removing: ./dataset/plus\A\A_left_A2912.jpg
# Removing: ./dataset/plus\A\A_left_A2913.jpg
# Removing: ./dataset/plus\A\A_left_A2914.jpg
# Removing: ./dataset/plus\A\A_left_A2915.jpg
# Removing: ./dataset/plus\A\A_left_A2916.jpg
# Removing: ./dataset/plus\A\A_left_A2917.jpg
# Removing: ./dataset/plus\A\A_left_A2918.jpg
# Removing: ./dataset/plus\A\A_left_A2919.jpg
# Removing: ./dataset/plus\A\A_left_A2920.jpg
# Removing: ./dataset/plus\A\A_left_A2921.jpg
# Removing: ./dataset/plus\A\A_left_A2922.jpg
# Removing: ./dataset/plus\A\A_left_A2923.jpg
# Removing: ./dataset/plus\A\A_left_A2924.jpg
# Removing: ./dataset/plus\A\A_left_A2925.jpg
# Removing: ./dataset/plus\A\A_left_A2926.jpg
# Removing: ./dataset/plus\A\A_left_A2927.jpg
# Removing: ./dataset/plus\A\A_left_A2928.jpg
# Removing: ./dataset/plus\A\A_left_A2929.jpg
# Removing: ./dataset/plus\A\A_left_A2930.jpg
# Removing: ./dataset/plus\A\A_left_A2931.jpg
# Removing: ./dataset/plus\A\A_left_A2932.jpg
# Removing: ./dataset/plus\A\A_left_A2933.jpg
# Removing: ./dataset/plus\A\A_left_A2934.jpg
# Removing: ./dataset/plus\A\A_left_A2935.jpg
# Removing: ./dataset/plus\A\A_left_A2936.jpg
# Removing: ./dataset/plus\A\A_left_A2938.jpg
# Removing: ./dataset/plus\A\A_left_A2939.jpg
# Removing: ./dataset/plus\A\A_left_A2940.jpg
# Removing: ./dataset/plus\A\A_left_A2942.jpg
# Removing: ./dataset/plus\A\A_left_A2944.jpg
# Removing: ./dataset/plus\A\A_left_A2945.jpg
# Removing: ./dataset/plus\A\A_left_A2946.jpg
# Removing: ./dataset/plus\A\A_left_A2947.jpg
# Removing: ./dataset/plus\A\A_left_A2948.jpg
# Removing: ./dataset/plus\A\A_left_A2949.jpg
# Removing: ./dataset/plus\A\A_left_A2950.jpg
# Removing: ./dataset/plus\A\A_left_A2951.jpg
# Removing: ./dataset/plus\A\A_left_A2952.jpg
# Removing: ./dataset/plus\A\A_left_A2953.jpg
# Removing: ./dataset/plus\A\A_left_A2954.jpg
# Removing: ./dataset/plus\A\A_left_A2960.jpg
# Removing: ./dataset/plus\A\A_left_A2961.jpg
# Removing: ./dataset/plus\A\A_left_A2962.jpg
# Removing: ./dataset/plus\A\A_left_A2970.jpg
# Removing: ./dataset/plus\A\A_left_A2972.jpg
# Removing: ./dataset/plus\A\A_left_A2973.jpg
# Removing: ./dataset/plus\A\A_left_A2974.jpg
# Removing: ./dataset/plus\A\A_left_A2975.jpg
# Removing: ./dataset/plus\A\A_left_A2977.jpg
# Removing: ./dataset/plus\A\A_left_A2988.jpg
# Removing: ./dataset/plus\A\A_left_A2989.jpg
# Removing: ./dataset/plus\A\A_left_A2990.jpg
# Removing: ./dataset/plus\A\A_left_A2991.jpg
# Removing: ./dataset/plus\A\A_left_A2992.jpg
# Removing: ./dataset/plus\A\A_left_A2993.jpg
# Removing: ./dataset/plus\A\A_left_A2994.jpg
# Removing: ./dataset/plus\A\A_left_A2995.jpg
# Removing: ./dataset/plus\A\A_left_A2996.jpg
# Removing: ./dataset/plus\A\A_left_A2997.jpg
# Removing: ./dataset/plus\A\A_left_A2998.jpg
# Removing: ./dataset/plus\A\A_left_A2999.jpg
# Removing: ./dataset/plus\A\A_left_A3000.jpg
# Removing: ./dataset/plus\A\A_left_A35.jpg
# Removing: ./dataset/plus\A\A_left_A36.jpg
# Removing: ./dataset/plus\A\A_left_A40.jpg
# Removing: ./dataset/plus\A\A_left_A47.jpg
# Removing: ./dataset/plus\A\A_left_A48.jpg
# Removing: ./dataset/plus\A\A_left_A49.jpg
# Removing: ./dataset/plus\A\A_left_A498.jpg
# Removing: ./dataset/plus\A\A_left_A500.jpg
# Removing: ./dataset/plus\A\A_left_A51.jpg
# Removing: ./dataset/plus\A\A_left_A52.jpg
# Removing: ./dataset/plus\A\A_left_A53.jpg
# Removing: ./dataset/plus\A\A_left_A54.jpg
# Removing: ./dataset/plus\A\A_left_A55.jpg
# Removing: ./dataset/plus\A\A_left_A57.jpg
# Removing: ./dataset/plus\A\A_left_A58.jpg
# Removing: ./dataset/plus\A\A_left_A59.jpg
# Removing: ./dataset/plus\A\A_left_A6.jpg
# Removing: ./dataset/plus\A\A_left_A60.jpg
# Removing: ./dataset/plus\A\A_left_A61.jpg
# Removing: ./dataset/plus\A\A_left_A62.jpg
# Removing: ./dataset/plus\A\A_left_A63.jpg
# Removing: ./dataset/plus\A\A_left_A64.jpg
# Removing: ./dataset/plus\A\A_left_A65.jpg
# Removing: ./dataset/plus\A\A_left_A66.jpg
# Removing: ./dataset/plus\A\A_left_A67.jpg
# Removing: ./dataset/plus\A\A_left_A68.jpg
# Removing: ./dataset/plus\A\A_left_A70.jpg
# Removing: ./dataset/plus\A\A_left_A71.jpg
# Removing: ./dataset/plus\A\A_left_A72.jpg
# Removing: ./dataset/plus\A\A_left_A73.jpg
# Removing: ./dataset/plus\A\A_left_A74.jpg
# Removing: ./dataset/plus\A\A_left_A75.jpg
# Removing: ./dataset/plus\A\A_left_A76.jpg
# Removing: ./dataset/plus\A\A_left_A77.jpg
# Removing: ./dataset/plus\A\A_left_A792.jpg
# Removing: ./dataset/plus\A\A_left_A794.jpg
# Removing: ./dataset/plus\A\A_left_A796.jpg
# Removing: ./dataset/plus\A\A_left_A798.jpg
# Removing: ./dataset/plus\A\A_left_A799.jpg
# Removing: ./dataset/plus\A\A_left_A801.jpg
# Removing: ./dataset/plus\A\A_left_A802.jpg
# Removing: ./dataset/plus\A\A_left_A803.jpg
# Removing: ./dataset/plus\A\A_left_A804.jpg
# Removing: ./dataset/plus\A\A_left_A805.jpg
# Removing: ./dataset/plus\A\A_left_A806.jpg
# Removing: ./dataset/plus\A\A_left_A807.jpg
# Removing: ./dataset/plus\A\A_left_A808.jpg
# Removing: ./dataset/plus\A\A_left_A809.jpg
# Removing: ./dataset/plus\A\A_left_A810.jpg
# Removing: ./dataset/plus\A\A_left_A811.jpg
# Removing: ./dataset/plus\A\A_left_A812.jpg
# Removing: ./dataset/plus\A\A_left_A813.jpg
# Removing: ./dataset/plus\A\A_left_A814.jpg
# Removing: ./dataset/plus\A\A_left_A815.jpg
# Removing: ./dataset/plus\A\A_left_A816.jpg
# Removing: ./dataset/plus\A\A_left_A817.jpg
# Removing: ./dataset/plus\A\A_left_A818.jpg
# Removing: ./dataset/plus\A\A_left_A819.jpg
# Removing: ./dataset/plus\A\A_left_A820.jpg
# Removing: ./dataset/plus\A\A_left_A821.jpg
# Removing: ./dataset/plus\A\A_left_A822.jpg
# Removing: ./dataset/plus\A\A_left_A823.jpg
# Removing: ./dataset/plus\A\A_left_A824.jpg
# Removing: ./dataset/plus\A\A_left_A825.jpg
# Removing: ./dataset/plus\A\A_left_A826.jpg
# Removing: ./dataset/plus\A\A_left_A827.jpg
# Removing: ./dataset/plus\A\A_left_A828.jpg
# Removing: ./dataset/plus\A\A_left_A829.jpg
# Removing: ./dataset/plus\A\A_left_A830.jpg
# Removing: ./dataset/plus\A\A_left_A831.jpg
# Removing: ./dataset/plus\A\A_left_A832.jpg
# Removing: ./dataset/plus\A\A_left_A833.jpg
# Removing: ./dataset/plus\A\A_left_A834.jpg
# Removing: ./dataset/plus\A\A_left_A835.jpg
# Removing: ./dataset/plus\A\A_left_A836.jpg
# Removing: ./dataset/plus\A\A_left_A837.jpg
# Removing: ./dataset/plus\A\A_left_A838.jpg
# Removing: ./dataset/plus\A\A_left_A839.jpg
# Removing: ./dataset/plus\A\A_left_A840.jpg
# Removing: ./dataset/plus\A\A_left_A841.jpg
# Removing: ./dataset/plus\A\A_left_A842.jpg
# Removing: ./dataset/plus\A\A_left_A843.jpg
# Removing: ./dataset/plus\A\A_left_A844.jpg
# Removing: ./dataset/plus\A\A_left_A845.jpg
# Removing: ./dataset/plus\A\A_left_A846.jpg
# Removing: ./dataset/plus\A\A_left_A847.jpg
# Removing: ./dataset/plus\A\A_left_A848.jpg
# Removing: ./dataset/plus\A\A_left_A849.jpg
# Removing: ./dataset/plus\A\A_left_A850.jpg
# Removing: ./dataset/plus\A\A_left_A851.jpg
# Removing: ./dataset/plus\A\A_left_A852.jpg
# Removing: ./dataset/plus\A\A_left_A853.jpg
# Removing: ./dataset/plus\A\A_left_A854.jpg
# Removing: ./dataset/plus\A\A_left_A855.jpg
# Removing: ./dataset/plus\A\A_left_A856.jpg
# Removing: ./dataset/plus\A\A_left_A857.jpg
# Removing: ./dataset/plus\A\A_left_A858.jpg
# Removing: ./dataset/plus\A\A_left_A859.jpg
# Removing: ./dataset/plus\A\A_left_A860.jpg
# Removing: ./dataset/plus\A\A_left_A861.jpg
# Removing: ./dataset/plus\A\A_left_A862.jpg
# Removing: ./dataset/plus\A\A_left_A863.jpg
# Removing: ./dataset/plus\A\A_left_A864.jpg
# Removing: ./dataset/plus\A\A_left_A865.jpg
# Removing: ./dataset/plus\A\A_left_A866.jpg
# Removing: ./dataset/plus\A\A_left_A867.jpg
# Removing: ./dataset/plus\A\A_left_A868.jpg
# Removing: ./dataset/plus\A\A_left_A869.jpg
# Removing: ./dataset/plus\A\A_left_A87.jpg
# Removing: ./dataset/plus\A\A_left_A870.jpg
# Removing: ./dataset/plus\A\A_left_A871.jpg
# Removing: ./dataset/plus\A\A_left_A872.jpg
# Removing: ./dataset/plus\A\A_left_A873.jpg
# Removing: ./dataset/plus\A\A_left_A874.jpg
# Removing: ./dataset/plus\A\A_left_A875.jpg
# Removing: ./dataset/plus\A\A_left_A876.jpg
# Removing: ./dataset/plus\A\A_left_A877.jpg
# Removing: ./dataset/plus\A\A_left_A878.jpg
# Removing: ./dataset/plus\A\A_left_A879.jpg
# Removing: ./dataset/plus\A\A_left_A880.jpg
# Removing: ./dataset/plus\A\A_left_A881.jpg
# Removing: ./dataset/plus\A\A_left_A882.jpg
# Removing: ./dataset/plus\A\A_left_A883.jpg
# Removing: ./dataset/plus\A\A_left_A884.jpg
# Removing: ./dataset/plus\A\A_left_A885.jpg
# Removing: ./dataset/plus\A\A_left_A886.jpg
# Removing: ./dataset/plus\A\A_left_A887.jpg
# Removing: ./dataset/plus\A\A_left_A888.jpg
# Removing: ./dataset/plus\A\A_left_A889.jpg
# Removing: ./dataset/plus\A\A_left_A890.jpg
# Removing: ./dataset/plus\A\A_left_A891.jpg
# Removing: ./dataset/plus\A\A_left_A892.jpg
# Removing: ./dataset/plus\A\A_left_A893.jpg
# Removing: ./dataset/plus\A\A_left_A894.jpg
# Removing: ./dataset/plus\A\A_left_A895.jpg
# Removing: ./dataset/plus\A\A_left_A896.jpg
# Removing: ./dataset/plus\A\A_left_A897.jpg
# Removing: ./dataset/plus\A\A_left_A898.jpg
# Removing: ./dataset/plus\A\A_left_A899.jpg
# Removing: ./dataset/plus\A\A_left_A90.jpg
# Removing: ./dataset/plus\A\A_left_A900.jpg
# Removing: ./dataset/plus\A\A_left_A901.jpg
# Removing: ./dataset/plus\A\A_left_A902.jpg
# Removing: ./dataset/plus\A\A_left_A903.jpg
# Removing: ./dataset/plus\A\A_left_A904.jpg
# Removing: ./dataset/plus\A\A_left_A905.jpg
# Removing: ./dataset/plus\A\A_left_A906.jpg
# Removing: ./dataset/plus\A\A_left_A907.jpg
# Removing: ./dataset/plus\A\A_left_A908.jpg
# Removing: ./dataset/plus\A\A_left_A909.jpg
# Removing: ./dataset/plus\A\A_left_A91.jpg
# Removing: ./dataset/plus\A\A_left_A911.jpg
# Removing: ./dataset/plus\A\A_left_A912.jpg
# Removing: ./dataset/plus\A\A_left_A913.jpg
# Removing: ./dataset/plus\A\A_left_A915.jpg
# Removing: ./dataset/plus\A\A_left_A92.jpg
# Removing: ./dataset/plus\A\A_left_A94.jpg
# Removing: ./dataset/plus\A\A_left_A95.jpg
# Removing: ./dataset/plus\A\A_left_A96.jpg
# Removing: ./dataset/plus\A\A_left_A97.jpg
# Removing: ./dataset/plus\A\A_left_A98.jpg
# Removing: ./dataset/plus\A\A_left_A99.jpg
# Removing: ./dataset/plus\A\A_right_A100.jpg
# Removing: ./dataset/plus\A\A_right_A101.jpg
# Removing: ./dataset/plus\A\A_right_A102.jpg
# Removing: ./dataset/plus\A\A_right_A103.jpg
# Removing: ./dataset/plus\A\A_right_A104.jpg
# Removing: ./dataset/plus\A\A_right_A105.jpg
# Removing: ./dataset/plus\A\A_right_A106.jpg
# Removing: ./dataset/plus\A\A_right_A107.jpg
# Removing: ./dataset/plus\A\A_right_A108.jpg
# Removing: ./dataset/plus\A\A_right_A1082.jpg
# Removing: ./dataset/plus\A\A_right_A109.jpg
# Removing: ./dataset/plus\A\A_right_A110.jpg
# Removing: ./dataset/plus\A\A_right_A111.jpg
# Removing: ./dataset/plus\A\A_right_A112.jpg
# Removing: ./dataset/plus\A\A_right_A113.jpg
# Removing: ./dataset/plus\A\A_right_A115.jpg
# Removing: ./dataset/plus\A\A_right_A116.jpg
# Removing: ./dataset/plus\A\A_right_A117.jpg
# Removing: ./dataset/plus\A\A_right_A118.jpg
# Removing: ./dataset/plus\A\A_right_A119.jpg
# Removing: ./dataset/plus\A\A_right_A120.jpg
# Removing: ./dataset/plus\A\A_right_A122.jpg
# Removing: ./dataset/plus\A\A_right_A123.jpg
# Removing: ./dataset/plus\A\A_right_A124.jpg
# Removing: ./dataset/plus\A\A_right_A125.jpg
# Removing: ./dataset/plus\A\A_right_A126.jpg
# Removing: ./dataset/plus\A\A_right_A127.jpg
# Removing: ./dataset/plus\A\A_right_A128.jpg
# Removing: ./dataset/plus\A\A_right_A129.jpg
# Removing: ./dataset/plus\A\A_right_A130.jpg
# Removing: ./dataset/plus\A\A_right_A131.jpg
# Removing: ./dataset/plus\A\A_right_A132.jpg
# Removing: ./dataset/plus\A\A_right_A133.jpg
# Removing: ./dataset/plus\A\A_right_A134.jpg
# Removing: ./dataset/plus\A\A_right_A1349.jpg
# Removing: ./dataset/plus\A\A_right_A135.jpg
# Removing: ./dataset/plus\A\A_right_A136.jpg
# Removing: ./dataset/plus\A\A_right_A137.jpg
# Removing: ./dataset/plus\A\A_right_A138.jpg
# Removing: ./dataset/plus\A\A_right_A139.jpg
# Removing: ./dataset/plus\A\A_right_A140.jpg
# Removing: ./dataset/plus\A\A_right_A141.jpg
# Removing: ./dataset/plus\A\A_right_A142.jpg
# Removing: ./dataset/plus\A\A_right_A143.jpg
# Removing: ./dataset/plus\A\A_right_A144.jpg
# Removing: ./dataset/plus\A\A_right_A145.jpg
# Removing: ./dataset/plus\A\A_right_A146.jpg
# Removing: ./dataset/plus\A\A_right_A147.jpg
# Removing: ./dataset/plus\A\A_right_A148.jpg
# Removing: ./dataset/plus\A\A_right_A149.jpg
# Removing: ./dataset/plus\A\A_right_A150.jpg
# Removing: ./dataset/plus\A\A_right_A152.jpg
# Removing: ./dataset/plus\A\A_right_A153.jpg
# Removing: ./dataset/plus\A\A_right_A154.jpg
# Removing: ./dataset/plus\A\A_right_A155.jpg
# Removing: ./dataset/plus\A\A_right_A156.jpg
# Removing: ./dataset/plus\A\A_right_A157.jpg
# Removing: ./dataset/plus\A\A_right_A158.jpg
# Removing: ./dataset/plus\A\A_right_A159.jpg
# Removing: ./dataset/plus\A\A_right_A160.jpg
# Removing: ./dataset/plus\A\A_right_A161.jpg
# Removing: ./dataset/plus\A\A_right_A162.jpg
# Removing: ./dataset/plus\A\A_right_A163.jpg
# Removing: ./dataset/plus\A\A_right_A164.jpg
# Removing: ./dataset/plus\A\A_right_A165.jpg
# Removing: ./dataset/plus\A\A_right_A166.jpg
# Removing: ./dataset/plus\A\A_right_A167.jpg
# Removing: ./dataset/plus\A\A_right_A168.jpg
# Removing: ./dataset/plus\A\A_right_A169.jpg
# Removing: ./dataset/plus\A\A_right_A170.jpg
# Removing: ./dataset/plus\A\A_right_A171.jpg
# Removing: ./dataset/plus\A\A_right_A172.jpg
# Removing: ./dataset/plus\A\A_right_A173.jpg
# Removing: ./dataset/plus\A\A_right_A174.jpg
# Removing: ./dataset/plus\A\A_right_A175.jpg
# Removing: ./dataset/plus\A\A_right_A176.jpg
# Removing: ./dataset/plus\A\A_right_A177.jpg
# Removing: ./dataset/plus\A\A_right_A178.jpg
# Removing: ./dataset/plus\A\A_right_A179.jpg
# Removing: ./dataset/plus\A\A_right_A180.jpg
# Removing: ./dataset/plus\A\A_right_A181.jpg
# Removing: ./dataset/plus\A\A_right_A182.jpg
# Removing: ./dataset/plus\A\A_right_A183.jpg
# Removing: ./dataset/plus\A\A_right_A184.jpg
# Removing: ./dataset/plus\A\A_right_A185.jpg
# Removing: ./dataset/plus\A\A_right_A186.jpg
# Removing: ./dataset/plus\A\A_right_A187.jpg
# Removing: ./dataset/plus\A\A_right_A188.jpg
# Removing: ./dataset/plus\A\A_right_A189.jpg
# Removing: ./dataset/plus\A\A_right_A191.jpg
# Removing: ./dataset/plus\A\A_right_A192.jpg
# Removing: ./dataset/plus\A\A_right_A193.jpg
# Removing: ./dataset/plus\A\A_right_A194.jpg
# Removing: ./dataset/plus\A\A_right_A195.jpg
# Removing: ./dataset/plus\A\A_right_A196.jpg
# Removing: ./dataset/plus\A\A_right_A197.jpg
# Removing: ./dataset/plus\A\A_right_A198.jpg
# Removing: ./dataset/plus\A\A_right_A199.jpg
# Removing: ./dataset/plus\A\A_right_A200.jpg
# Removing: ./dataset/plus\A\A_right_A201.jpg
# Removing: ./dataset/plus\A\A_right_A202.jpg
# Removing: ./dataset/plus\A\A_right_A203.jpg
# Removing: ./dataset/plus\A\A_right_A204.jpg
# Removing: ./dataset/plus\A\A_right_A205.jpg
# Removing: ./dataset/plus\A\A_right_A206.jpg
# Removing: ./dataset/plus\A\A_right_A207.jpg
# Removing: ./dataset/plus\A\A_right_A208.jpg
# Removing: ./dataset/plus\A\A_right_A209.jpg
# Removing: ./dataset/plus\A\A_right_A210.jpg
# Removing: ./dataset/plus\A\A_right_A211.jpg
# Removing: ./dataset/plus\A\A_right_A212.jpg
# Removing: ./dataset/plus\A\A_right_A213.jpg
# Removing: ./dataset/plus\A\A_right_A214.jpg
# Removing: ./dataset/plus\A\A_right_A215.jpg
# Removing: ./dataset/plus\A\A_right_A216.jpg
# Removing: ./dataset/plus\A\A_right_A217.jpg
# Removing: ./dataset/plus\A\A_right_A218.jpg
# Removing: ./dataset/plus\A\A_right_A219.jpg
# Removing: ./dataset/plus\A\A_right_A220.jpg
# Removing: ./dataset/plus\A\A_right_A221.jpg
# Removing: ./dataset/plus\A\A_right_A222.jpg
# Removing: ./dataset/plus\A\A_right_A223.jpg
# Removing: ./dataset/plus\A\A_right_A224.jpg
# Removing: ./dataset/plus\A\A_right_A225.jpg
# Removing: ./dataset/plus\A\A_right_A226.jpg
# Removing: ./dataset/plus\A\A_right_A227.jpg
# Removing: ./dataset/plus\A\A_right_A2271.jpg
# Removing: ./dataset/plus\A\A_right_A228.jpg
# Removing: ./dataset/plus\A\A_right_A229.jpg
# Removing: ./dataset/plus\A\A_right_A230.jpg
# Removing: ./dataset/plus\A\A_right_A2301.jpg
# Removing: ./dataset/plus\A\A_right_A231.jpg
# Removing: ./dataset/plus\A\A_right_A2315.jpg
# Removing: ./dataset/plus\A\A_right_A232.jpg
# Removing: ./dataset/plus\A\A_right_A233.jpg
# Removing: ./dataset/plus\A\A_right_A234.jpg
# Removing: ./dataset/plus\A\A_right_A235.jpg
# Removing: ./dataset/plus\A\A_right_A236.jpg
# Removing: ./dataset/plus\A\A_right_A237.jpg
# Removing: ./dataset/plus\A\A_right_A238.jpg
# Removing: ./dataset/plus\A\A_right_A239.jpg
# Removing: ./dataset/plus\A\A_right_A240.jpg
# Removing: ./dataset/plus\A\A_right_A2409.jpg
# Removing: ./dataset/plus\A\A_right_A241.jpg
# Removing: ./dataset/plus\A\A_right_A2410.jpg
# Removing: ./dataset/plus\A\A_right_A2412.jpg
# Removing: ./dataset/plus\A\A_right_A2419.jpg
# Removing: ./dataset/plus\A\A_right_A242.jpg
# Removing: ./dataset/plus\A\A_right_A2420.jpg
# Removing: ./dataset/plus\A\A_right_A2422.jpg
# Removing: ./dataset/plus\A\A_right_A2423.jpg
# Removing: ./dataset/plus\A\A_right_A2424.jpg
# Removing: ./dataset/plus\A\A_right_A2425.jpg
# Removing: ./dataset/plus\A\A_right_A2426.jpg
# Removing: ./dataset/plus\A\A_right_A2427.jpg
# Removing: ./dataset/plus\A\A_right_A2428.jpg
# Removing: ./dataset/plus\A\A_right_A243.jpg
# Removing: ./dataset/plus\A\A_right_A2430.jpg
# Removing: ./dataset/plus\A\A_right_A2432.jpg
# Removing: ./dataset/plus\A\A_right_A2433.jpg
# Removing: ./dataset/plus\A\A_right_A2434.jpg
# Removing: ./dataset/plus\A\A_right_A2435.jpg
# Removing: ./dataset/plus\A\A_right_A2436.jpg
# Removing: ./dataset/plus\A\A_right_A2437.jpg
# Removing: ./dataset/plus\A\A_right_A2438.jpg
# Removing: ./dataset/plus\A\A_right_A2439.jpg
# Removing: ./dataset/plus\A\A_right_A244.jpg
# Removing: ./dataset/plus\A\A_right_A2440.jpg
# Removing: ./dataset/plus\A\A_right_A2441.jpg
# Removing: ./dataset/plus\A\A_right_A2442.jpg
# Removing: ./dataset/plus\A\A_right_A2443.jpg
# Removing: ./dataset/plus\A\A_right_A2444.jpg
# Removing: ./dataset/plus\A\A_right_A245.jpg
# Removing: ./dataset/plus\A\A_right_A2457.jpg
# Removing: ./dataset/plus\A\A_right_A2458.jpg
# Removing: ./dataset/plus\A\A_right_A2459.jpg
# Removing: ./dataset/plus\A\A_right_A246.jpg
# Removing: ./dataset/plus\A\A_right_A2460.jpg
# Removing: ./dataset/plus\A\A_right_A2461.jpg
# Removing: ./dataset/plus\A\A_right_A2464.jpg
# Removing: ./dataset/plus\A\A_right_A2465.jpg
# Removing: ./dataset/plus\A\A_right_A2466.jpg
# Removing: ./dataset/plus\A\A_right_A2467.jpg
# Removing: ./dataset/plus\A\A_right_A2468.jpg
# Removing: ./dataset/plus\A\A_right_A2469.jpg
# Removing: ./dataset/plus\A\A_right_A247.jpg
# Removing: ./dataset/plus\A\A_right_A2470.jpg
# Removing: ./dataset/plus\A\A_right_A2471.jpg
# Removing: ./dataset/plus\A\A_right_A2472.jpg
# Removing: ./dataset/plus\A\A_right_A2473.jpg
# Removing: ./dataset/plus\A\A_right_A2474.jpg
# Removing: ./dataset/plus\A\A_right_A2475.jpg
# Removing: ./dataset/plus\A\A_right_A2476.jpg
# Removing: ./dataset/plus\A\A_right_A2477.jpg
# Removing: ./dataset/plus\A\A_right_A2478.jpg
# Removing: ./dataset/plus\A\A_right_A2479.jpg
# Removing: ./dataset/plus\A\A_right_A248.jpg
# Removing: ./dataset/plus\A\A_right_A2480.jpg
# Removing: ./dataset/plus\A\A_right_A2481.jpg
# Removing: ./dataset/plus\A\A_right_A2482.jpg
# Removing: ./dataset/plus\A\A_right_A2483.jpg
# Removing: ./dataset/plus\A\A_right_A2484.jpg
# Removing: ./dataset/plus\A\A_right_A2485.jpg
# Removing: ./dataset/plus\A\A_right_A2487.jpg
# Removing: ./dataset/plus\A\A_right_A2488.jpg
# Removing: ./dataset/plus\A\A_right_A2489.jpg
# Removing: ./dataset/plus\A\A_right_A249.jpg
# Removing: ./dataset/plus\A\A_right_A2490.jpg
# Removing: ./dataset/plus\A\A_right_A2491.jpg
# Removing: ./dataset/plus\A\A_right_A2492.jpg
# Removing: ./dataset/plus\A\A_right_A2493.jpg
# Removing: ./dataset/plus\A\A_right_A2494.jpg
# Removing: ./dataset/plus\A\A_right_A2495.jpg
# Removing: ./dataset/plus\A\A_right_A2496.jpg
# Removing: ./dataset/plus\A\A_right_A2497.jpg
# Removing: ./dataset/plus\A\A_right_A2498.jpg
# Removing: ./dataset/plus\A\A_right_A2499.jpg
# Removing: ./dataset/plus\A\A_right_A250.jpg
# Removing: ./dataset/plus\A\A_right_A2500.jpg
# Removing: ./dataset/plus\A\A_right_A2501.jpg
# Removing: ./dataset/plus\A\A_right_A2502.jpg
# Removing: ./dataset/plus\A\A_right_A2503.jpg
# Removing: ./dataset/plus\A\A_right_A2504.jpg
# Removing: ./dataset/plus\A\A_right_A2505.jpg
# Removing: ./dataset/plus\A\A_right_A2506.jpg
# Removing: ./dataset/plus\A\A_right_A2507.jpg
# Removing: ./dataset/plus\A\A_right_A2508.jpg
# Removing: ./dataset/plus\A\A_right_A2509.jpg
# Removing: ./dataset/plus\A\A_right_A251.jpg
# Removing: ./dataset/plus\A\A_right_A2510.jpg
# Removing: ./dataset/plus\A\A_right_A2511.jpg
# Removing: ./dataset/plus\A\A_right_A2512.jpg
# Removing: ./dataset/plus\A\A_right_A2513.jpg
# Removing: ./dataset/plus\A\A_right_A2514.jpg
# Removing: ./dataset/plus\A\A_right_A2515.jpg
# Removing: ./dataset/plus\A\A_right_A2516.jpg
# Removing: ./dataset/plus\A\A_right_A2517.jpg
# Removing: ./dataset/plus\A\A_right_A2518.jpg
# Removing: ./dataset/plus\A\A_right_A2519.jpg
# Removing: ./dataset/plus\A\A_right_A252.jpg
# Removing: ./dataset/plus\A\A_right_A2520.jpg
# Removing: ./dataset/plus\A\A_right_A2521.jpg
# Removing: ./dataset/plus\A\A_right_A2522.jpg
# Removing: ./dataset/plus\A\A_right_A2524.jpg
# Removing: ./dataset/plus\A\A_right_A2525.jpg
# Removing: ./dataset/plus\A\A_right_A2526.jpg
# Removing: ./dataset/plus\A\A_right_A2527.jpg
# Removing: ./dataset/plus\A\A_right_A2528.jpg
# Removing: ./dataset/plus\A\A_right_A2529.jpg
# Removing: ./dataset/plus\A\A_right_A253.jpg
# Removing: ./dataset/plus\A\A_right_A2530.jpg
# Removing: ./dataset/plus\A\A_right_A2531.jpg
# Removing: ./dataset/plus\A\A_right_A2532.jpg
# Removing: ./dataset/plus\A\A_right_A2533.jpg
# Removing: ./dataset/plus\A\A_right_A2534.jpg
# Removing: ./dataset/plus\A\A_right_A254.jpg
# Removing: ./dataset/plus\A\A_right_A2544.jpg
# Removing: ./dataset/plus\A\A_right_A2545.jpg
# Removing: ./dataset/plus\A\A_right_A2546.jpg
# Removing: ./dataset/plus\A\A_right_A2547.jpg
# Removing: ./dataset/plus\A\A_right_A2548.jpg
# Removing: ./dataset/plus\A\A_right_A2549.jpg
# Removing: ./dataset/plus\A\A_right_A255.jpg
# Removing: ./dataset/plus\A\A_right_A2550.jpg
# Removing: ./dataset/plus\A\A_right_A2551.jpg
# Removing: ./dataset/plus\A\A_right_A2552.jpg
# Removing: ./dataset/plus\A\A_right_A2553.jpg
# Removing: ./dataset/plus\A\A_right_A2554.jpg
# Removing: ./dataset/plus\A\A_right_A2555.jpg
# Removing: ./dataset/plus\A\A_right_A2556.jpg
# Removing: ./dataset/plus\A\A_right_A2557.jpg
# Removing: ./dataset/plus\A\A_right_A2558.jpg
# Removing: ./dataset/plus\A\A_right_A2559.jpg
# Removing: ./dataset/plus\A\A_right_A256.jpg
# Removing: ./dataset/plus\A\A_right_A2561.jpg
# Removing: ./dataset/plus\A\A_right_A2562.jpg
# Removing: ./dataset/plus\A\A_right_A2567.jpg
# Removing: ./dataset/plus\A\A_right_A2568.jpg
# Removing: ./dataset/plus\A\A_right_A2569.jpg
# Removing: ./dataset/plus\A\A_right_A257.jpg
# Removing: ./dataset/plus\A\A_right_A2570.jpg
# Removing: ./dataset/plus\A\A_right_A2571.jpg
# Removing: ./dataset/plus\A\A_right_A2572.jpg
# Removing: ./dataset/plus\A\A_right_A2575.jpg
# Removing: ./dataset/plus\A\A_right_A2577.jpg
# Removing: ./dataset/plus\A\A_right_A2579.jpg
# Removing: ./dataset/plus\A\A_right_A258.jpg
# Removing: ./dataset/plus\A\A_right_A2580.jpg
# Removing: ./dataset/plus\A\A_right_A2581.jpg
# Removing: ./dataset/plus\A\A_right_A2582.jpg
# Removing: ./dataset/plus\A\A_right_A2583.jpg
# Removing: ./dataset/plus\A\A_right_A2584.jpg
# Removing: ./dataset/plus\A\A_right_A2585.jpg
# Removing: ./dataset/plus\A\A_right_A2586.jpg
# Removing: ./dataset/plus\A\A_right_A2587.jpg
# Removing: ./dataset/plus\A\A_right_A2588.jpg
# Removing: ./dataset/plus\A\A_right_A2589.jpg
# ...
# Removing: ./dataset/plus\Z\Z_right_Z2568.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2569.jpg
# Removing: ./dataset/plus\Z\Z_right_Z257.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2570.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2571.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2572.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2573.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2574.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2575.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2576.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2577.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2578.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2579.jpg
# Removing: ./dataset/plus\Z\Z_right_Z258.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2580.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2581.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2582.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2583.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2584.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2585.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2586.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2587.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2588.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2589.jpg
# Removing: ./dataset/plus\Z\Z_right_Z259.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2590.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2591.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2592.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2593.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2594.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2595.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2596.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2597.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2598.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2599.jpg
# Removing: ./dataset/plus\Z\Z_right_Z26.jpg
# Removing: ./dataset/plus\Z\Z_right_Z260.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2600.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2601.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2602.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2603.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2604.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2605.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2606.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2607.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2608.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2609.jpg
# Removing: ./dataset/plus\Z\Z_right_Z261.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2610.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2611.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2612.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2613.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2614.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2615.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2616.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2617.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2618.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2619.jpg
# Removing: ./dataset/plus\Z\Z_right_Z262.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2620.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2621.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2622.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2623.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2624.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2625.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2626.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2627.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2628.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2629.jpg
# Removing: ./dataset/plus\Z\Z_right_Z263.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2630.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2631.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2632.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2633.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2634.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2635.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2636.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2637.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2638.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2639.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2641.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2642.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2643.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2644.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2645.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2646.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2647.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2648.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2649.jpg
# Removing: ./dataset/plus\Z\Z_right_Z265.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2650.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2651.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2652.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2653.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2654.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2655.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2656.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2657.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2658.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2659.jpg
# Removing: ./dataset/plus\Z\Z_right_Z266.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2660.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2661.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2662.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2663.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2664.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2665.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2666.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2667.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2668.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2669.jpg
# Removing: ./dataset/plus\Z\Z_right_Z267.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2670.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2671.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2672.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2673.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2674.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2675.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2676.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2677.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2678.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2679.jpg
# Removing: ./dataset/plus\Z\Z_right_Z268.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2680.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2681.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2682.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2683.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2684.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2685.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2686.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2687.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2688.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2689.jpg
# Removing: ./dataset/plus\Z\Z_right_Z269.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2690.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2691.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2692.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2693.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2694.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2695.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2696.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2697.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2698.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2699.jpg
# Removing: ./dataset/plus\Z\Z_right_Z270.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2700.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2701.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2702.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2703.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2704.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2705.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2706.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2707.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2708.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2709.jpg
# Removing: ./dataset/plus\Z\Z_right_Z271.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2710.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2711.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2712.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2713.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2714.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2715.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2716.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2717.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2718.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2719.jpg
# Removing: ./dataset/plus\Z\Z_right_Z272.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2720.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2721.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2722.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2723.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2724.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2725.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2726.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2727.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2728.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2729.jpg
# Removing: ./dataset/plus\Z\Z_right_Z273.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2730.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2731.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2732.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2733.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2734.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2735.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2736.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2737.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2738.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2739.jpg
# Removing: ./dataset/plus\Z\Z_right_Z274.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2740.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2741.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2742.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2743.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2744.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2745.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2746.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2747.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2748.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2749.jpg
# Removing: ./dataset/plus\Z\Z_right_Z275.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2750.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2751.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2752.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2753.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2754.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2755.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2756.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2757.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2758.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2759.jpg
# Removing: ./dataset/plus\Z\Z_right_Z276.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2760.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2761.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2762.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2763.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2764.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2765.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2766.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2767.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2768.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2769.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2770.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2771.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2772.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2773.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2774.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2775.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2776.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2777.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2778.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2779.jpg
# Removing: ./dataset/plus\Z\Z_right_Z278.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2780.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2781.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2782.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2783.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2784.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2785.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2786.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2787.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2788.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2789.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2790.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2791.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2792.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2793.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2794.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2795.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2796.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2797.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2798.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2799.jpg
# Removing: ./dataset/plus\Z\Z_right_Z28.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2800.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2801.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2802.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2803.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2804.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2805.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2806.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2807.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2808.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2809.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2810.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2811.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2812.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2813.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2814.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2815.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2816.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2817.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2818.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2819.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2820.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2821.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2822.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2823.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2824.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2825.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2826.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2827.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2828.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2829.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2830.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2831.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2832.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2833.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2834.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2835.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2836.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2837.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2838.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2839.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2840.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2841.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2842.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2843.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2844.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2845.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2846.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2847.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2848.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2849.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2850.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2851.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2852.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2853.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2854.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2855.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2856.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2857.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2858.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2859.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2860.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2861.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2862.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2863.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2864.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2865.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2866.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2867.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2868.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2869.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2870.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2871.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2872.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2873.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2874.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2875.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2876.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2877.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2878.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2879.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2880.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2881.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2882.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2883.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2884.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2885.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2886.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2887.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2888.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2889.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2890.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2891.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2904.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2988.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2995.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2998.jpg
# Removing: ./dataset/plus\Z\Z_right_Z2999.jpg
# Removing: ./dataset/plus\Z\Z_right_Z3000.jpg
# Removing: ./dataset/plus\Z\Z_right_Z4.jpg
# Removing: ./dataset/plus\Z\Z_right_Z5.jpg
# Removing: ./dataset/plus\Z\Z_right_Z7.jpg
# Removing: ./dataset/plus\Z\Z_right_Z8.jpg
# Removing: ./dataset/plus\Z\Z_right_Z9.jpg
